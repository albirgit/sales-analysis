# %%
import pandas as pd

# %%
df = pd.read_csv("../data/Ecommerce_Sales_Data_2024_2025.csv")

# %% [markdown]
# ### Top Selling Category ( quantity wise )

# %%
query = """
SELECT Category, SUM(Quantity) AS total_quantity
FROM sales
GROUP BY Category
ORDER BY total_quantity DESC
LIMIT 1;
"""

pd.read_sql(query, conn)
# Out:
#     Category  total_quantity
# 0  Furniture            1591

# %% [markdown]
# ### Top Selling Category ( sales wise )

# %%
query = """
SELECT Category, SUM(Sales) AS total_sales
FROM sales
GROUP BY Category
ORDER BY total_sales DESC
LIMIT 1;
"""

pd.read_sql(query, conn)
# Out:
#      Category  total_sales
# 0  Home Decor  57233222.35

# %% [markdown]
# ### Highest Selling Month

# %%
query = """
SELECT strftime('%Y-%m', "Order Date") AS year_month, SUM(Sales) AS sales
FROM sales
GROUP BY year_month
ORDER BY sales DESC
LIMIT 1;
"""

pd.read_sql(query, conn)
# Out:
#   year_month        sales
# 0    2025-05  26010928.65

# %% [markdown]
# ### City with Highest Profit

# %%
query = """
SELECT City, SUM(Profit) AS total_profit
FROM sales
GROUP BY City
ORDER BY total_profit DESC
LIMIT 1;
"""

pd.read_sql(query, conn)
# Out:
#       City  total_profit
# 0  Lucknow    4523681.09

# %% [markdown]
# ### Top 3 Cities by Profit

# %%
query = """
SELECT City, SUM(Profit) AS total_profit
FROM sales
GROUP BY City
ORDER BY total_profit DESC
LIMIT 3;
"""

pd.read_sql(query, conn)
# Out:
#         City  total_profit
# 0    Lucknow    4523681.09
# 1   Guwahati    4487271.28
# 2  Bangalore    4416914.72
